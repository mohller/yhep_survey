# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# ### Choose the palette

# %%
# This is the colorset used in the BMBAF presentation
original_colorset = ['#72B4DE', '#F19F85', '#7AE17A', '#E4E577', '#B6D1B3', '#DFCDB5', '#FEF1EB', '#66CBC6', '#C8D6E5', '#E8C1E5', '#BDBDF7']

colorset = original_colorset

# %% [markdown]
# # Diggest of Survey by yHEP

# %%
table = pd.read_csv('results-survey548259_all_replies.csv')

dropped_cols = []
#dropping all NaN columns
for col in table.columns:
    try:
        if np.all(np.isnan(table[col])):
            dropped_cols.append(col)
    except:
        continue
        
table.drop(dropped_cols, inplace=True, axis=1)
print('Dropped columns: ', dropped_cols)

table
# Out:
# Dropped columns:  ['Are you an EU citizen? [Other]', 'How?', 'Would you choose HEP again? [Other]', 'Has the feeling of imposter syndrome impacted your work, like hesitancy not to present your research, insecurity in leading a team or project, etc.?  [Other]', 'Question time: GeQ1', 'Question time: GeQ2', 'Question time: GeQ3', 'Question time: GeQ4', 'Question time: GeQ5', 'Question time: GeQ6', 'Question time: GeQ7', 'Question time: GeQ8', 'Question time: GeQ8experiment1', 'Question time: GeQ8experiment2', 'Question time: WoQ1', 'Question time: WoQ2', 'Question time: WoQ3', 'Question time: WoQ4', 'Question time: WoQ7', 'Question time: WoQ8', 'Question time: WoQ9', 'Question time: WoQ10', 'Question time: WoQ10bachmast1', 'Question time: WoQ10phd1', 'Question time: WoQ10phd2', 'Question time: WoQ10phd3', 'Question time: WoQ10phd4', 'Question time: WoQ10postdoc1', 'Question time: WoQ10postdoc2', 'Question time: WoQ10postdoc3', 'Question time: WoQ11', 'Question time: WoQ12', 'Question time: WoQ13', 'Question time: WoQ14', 'Question time: FI1', 'Question time: Fi2', 'Question time: Fi2BMBFaff', 'Question time: Fi2Responsible', 'Question time: Fi4PhDonly', 'Question time: Fi5PDonly', 'Question time: Fi6PDonly', 'Question time: Fi7PDonly', 'Question time: WL1', 'Question time: WL2', 'Question time: WL2overwork1', 'Question time: WL2overwork2', 'Question time: WL5', 'Question time: WL8', 'Question time: WL9', 'Question time: WL10', 'Question time: WL12', 'Question time: WL13', 'Question time: WL14', 'Question time: WL14children1', 'Question time: WL14children2', 'Question time: WL14children3', 'Question time: WL14children4', 'Question time: WL14elderly1', 'Question time: WL14elderly2', 'Question time: WL14elderly3', 'Question time: WL14elderly4', 'Question time: Ca1', 'Question time: Ca2', 'Question time: Ca4', 'Question time: Ca5', 'Question time: Ca6', 'Question time: Ca8', 'Question time: CD1', 'Question time: CD1factor', 'Question time: CD1factor2', 'Question time: CD2', 'Question time: CD3', 'Question time: CD4', 'Question time: CD4impost1', 'Question time: CD4impost2', 'Question time: FeQ1']
#      Response ID       Date submitted  Last page Start language        Seed  \
# 0              1  2022-02-23 14:58:42          7             en  1290317997
# 1              2  2022-02-23 14:24:09          7             en   275826069
# 2              4  2022-02-23 14:58:17          7             en  1435481450
# 3              8  2022-02-23 16:29:51          7             en   854324577
# 4             10  2022-02-23 16:31:53          7             en  2063434916
# ..           ...                  ...        ...            ...         ...
# 126          192  2022-03-09 18:07:15          7             en   367451451
# 127          193  2022-03-09 19:21:13          7             en  1117698103
# 128          194  2022-03-09 21:08:43          7             en   691183543
# 129          196  2022-03-10 10:53:33          7             en  1741961637
# 130          197  2022-03-10 15:57:02          7             en   717037738
#
#             Date started     Date last action  \
# 0    2022-02-23 12:26:20  2022-02-23 14:58:42
# 1    2022-02-23 13:53:40  2022-02-23 14:24:09
# 2    2022-02-23 14:48:50  2022-02-23 14:58:17
# 3    2022-02-23 16:19:17  2022-02-23 16:29:51
# 4    2022-02-23 16:21:55  2022-02-23 16:31:53
# ..                   ...                  ...
# 126  2022-03-09 17:50:52  2022-03-09 18:07:15
# 127  2022-03-09 19:09:50  2022-03-09 19:21:13
# 128  2022-03-09 21:01:00  2022-03-09 21:08:42
# 129  2022-03-10 10:43:27  2022-03-10 10:53:33
# 130  2022-03-10 14:52:17  2022-03-10 15:57:02
#
#                                  IP address  \
# 0                             87.163.223.93
# 1     2003:e2:af2e:4177:18f3:ddc4:852d:6d06
# 2    2001:9e8:62da:6500:9951:ecc1:35c5:71bc
# 3                           131.169.210.105
# 4                            131.169.235.47
# ..                                      ...
# 126                          131.169.139.17
# 127                         134.100.104.202
# 128                    2a00:5ba0:0:3800::8b
# 129   2003:e0:a734:e3ee:39af:1e69:3f37:ffe0
# 130  2a01:c23:6c75:b200:5db1:7836:4d2e:5fcb
#
#                         What is your current position?  \
# 0                                              PostDoc
# 1                                              PostDoc
# 2    Junior research group leader, Akademische/r Ra...
# 3                                          PhD student
# 4                                          PhD student
# ..                                                 ...
# 126                                        PhD student
# 127  Junior research group leader, Akademische/r Ra...
# 128                                     Master student
# 129                                   Bachelor student
# 130                                   Bachelor student
#
#     What is your current position? [Other]  ...  \
# 0                                      NaN  ...
# 1                                      NaN  ...
# 2                                      NaN  ...
# 3                                      NaN  ...
# 4                                      NaN  ...
# ..                                     ...  ...
# 126                                    NaN  ...
# 127                                    NaN  ...
# 128                                    NaN  ...
# 129                                    NaN  ...
# 130                                    NaN  ...
#
#     What has helped you or would have helped you to handle feelings of imposter syndrome better?  \
# 0    More productive environments of discussion, le...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 126                                                NaN
# 127                                                NaN
# 128                                        No idea ...
# 129                                                NaN
# 130  Time. I need to et used to the idea, that my i...
#
#     Anything else that you would like to communicate to us? Total time  \
# 0                                                  NaN         9145.94
# 1                                                  NaN         1834.11
# 2                                                  NaN          570.45
# 3                                                  NaN          636.63
# 4                                                  NaN          601.32
# ..                                                 ...             ...
# 126                                                NaN          986.30
# 127                                                NaN          683.66
# 128                                                NaN          464.51
# 129                                                NaN          608.19
# 130  During corona i felt so alone, because everyon...         3886.31
#
#     Group time: General Group time: Work situation  \
# 0                 80.85                    1302.13
# 1                 49.68                     787.84
# 2                 33.21                     106.74
# 3                 32.12                     152.26
# 4                 49.44                     138.15
# ..                  ...                        ...
# 126               56.37                     364.41
# 127               65.19                     156.12
# 128               82.32                     140.02
# 129               52.91                     151.46
# 130               96.03                    1897.62
#
#     Group time: Financial/contract situation Group time: Work-life balance  \
# 0                                    5260.83                        905.35
# 1                                     128.46                        669.66
# 2                                     138.66                         91.09
# 3                                      49.46                        199.17
# 4                                      47.27                        155.70
# ..                                       ...                           ...
# 126                                   108.44                        211.22
# 127                                   113.46                        163.51
# 128                                      NaN                        102.07
# 129                                      NaN                        157.53
# 130                                      NaN                        412.14
#
#     Group time: Career paths Group time: Diversity and Inclusion  \
# 0                     624.82                              920.50
# 1                     148.94                               44.79
# 2                     133.68                               60.89
# 3                     150.80                               50.26
# 4                     160.93                               46.36
# ..                       ...                                 ...
# 126                   177.41                               64.60
# 127                   143.97                               38.40
# 128                    87.69                               49.41
# 129                   194.47                               48.65
# 130                   315.16                              535.29
#
#     Group time: Feedback
# 0                  51.46
# 1                   4.74
# 2                   6.18
# 3                   2.56
# 4                   3.47
# ..                   ...
# 126                 3.85
# 127                 3.01
# 128                 3.00
# 129                 3.17
# 130               630.07
#
# [131 rows x 213 columns]

# %% [markdown]
# ### The questions (dataframe columns) are these

# %%
# print('\t\t'.join([col[:15]+'...'+col[-15:] for col in table.columns]) )
for col in table.columns:
    print(col)
# Out:
# Response ID
# Date submitted
# Last page
# Start language
# Seed
# Date started
# Date last action
# IP address
# What is your current position?
# What is your current position? [Other]
# Are you an EU citizen?
# Do you speak German fluently?
# Do you speak German fluently? [Other]
# What is your gender?
# What is your gender? [Other]
# Which federated state in Germany do you work in?
# Which federated state in Germany do you work in? [Other]
# Which yHEP section do you see yourself in?
# Which yHEP section do you see yourself in? [Other]
# What is your main work environment?
# What is your main work environment? [Other]
# Under which category does your work fall mainly?
# Under which category does your work fall mainly?  [Other]
# What is the main focus of your work?
# What is the main focus of your work? [Other]
# How large is the experimental collaboration you work in?
# Why are you working/studying in HEP? [Liked the topic/area of physics]
# Why are you working/studying in HEP? [Liked the work environment]
# Why are you working/studying in HEP? [Liked the supervisor]
# Why are you working/studying in HEP? [Was fascinated by the large experiments]
# Why are you working/studying in HEP? [Based on the working conditions / career prospects]
# Why are you working/studying in HEP? [Other]
# We are interested to hear about your work situation [Are you happy with your work situation?]
# We are interested to hear about your work situation [Do you have the impression that your work is well seen and you receive proper recognition?]
# We are interested to hear about your work situation [Do you have sufficient scientific freedom?]
# What do you appreciate about the research and academic system in Germany?
# What do you dislike about the research and academic system in Germany and how could it be improved?
# We are interested to hear your opinion on the topic of engagement with the public for scientists [How important do you consider engagement with the public for scientists?]
# We are interested to hear your opinion on the topic of engagement with the public for scientists [Do you have enough time for public engagement to get involved as much as you like?]
# Do you have to teach as part of your current position?
# Do you have to teach as part of your current position? [Other]
# We are interested to hear your opinion on the topic of teaching [Do you have the impression that the level and amount of teaching is adequate for your current position?]
# We are interested to hear your opinion on the topic of teaching [Do you have the impression that teaching is valued sufficiently?]
# How could the value of teaching be improved?
# We are interested to hear your opinion on your bachelor / master thesis [Do you have the impression that with your bachelor / master thesis, you are providing an important contribution to your field?]
# We are interested to hear your opinion on your bachelor / master thesis [Are you satisfied with the relationship with your supervisor(s)?]
# We are interested to hear your opinion on your bachelor / master thesis [Are you satisfied with the internal relationship within your supervisor's group?]
# We are interested to hear your opinion on your doctoral / PhD studies and thesis [Do you have the impression that with your doctoral / PhD thesis you are providing an important contribution to your field?]
# We are interested to hear your opinion on your doctoral / PhD studies and thesis [Are you happy with your supervision?]
# We are interested to hear your opinion on your doctoral / PhD studies and thesis [Do you think your thesis is well planned?]
# Who is planning your thesis?
# Who is planning your thesis? [Other]
# How long are your doctoral / PhD studies planned to last?
# How long are your doctoral / PhD studies planned to last? [Other]
# What could be done to improve your supervision situation?
# How long did it take you to complete your doctorate / PhD?
# How long did it take you to complete your doctorate / PhD? [Other]
# How long do you think doctoral / PhD studies should last?
# How long do you think doctoral / PhD studies should last? [Other]
# How well does your supervisor provide you with guidance and support for your work and career development?
# We are interested to hear your opinion on environmental sustainability in science [How important is environmental sustainability in science to you?]
# We are interested to hear your opinion on environmental sustainability in science [How well do you think sustainability in science is approached in your project / institute?]
# What would you like to see implemented / done to improve environmental sustainability in science?
# We are interested to hear your opinion on the future of the field [Do you have the impression that you are sufficiently involved in strategic discussions and decisions on the future of your field?]
# We are interested to hear your opinion on the future of the field [Do you think that the scientific opinion of young researchers is properly taking into account within your collaboration / working group?]
# We are interested to hear your opinion on the future of the field [Do you think yHEP represents your community well?]
# What topics do you think yHEP should address more / in addition?
# How is your current position funded?
# How is your current position funded? [Other]
# A few questions on your contract situation: [Have you ever encountered short periods of unemployment because of non-matching contracts?]
# A few questions on your contract situation: [Were you affected (directly or indirectly) by the late funding notifications of the BMBF in 2021?]
# A few questions on your contract situation: [Do you think your non-permanent contract situation prevents you from having a position of responsibility?]
# A few questions on your contract situation: [Do you think your position gives you adequate financial stability?]
# You selected that you were affected by the late funding notification of the BMBF in 2021 or "other". What would have helped you? Do you want to give a comment?
# You selected "Yes" or "Other" on the question regarding the position of responsibility. Do you want to provide a comment?
# What kind of TV-L E13 contract do you have?
# For how long have you been a Postdoc (in years)?
# What is the total duration of the contract you are currently on (form its beginning to its end) in years?
# What is the total duration of the contract you are currently on (form its beginning to its end) in years?  [Other]
# Contract and funding situation [Do you think your contract duration is adequate? ]
# Contract and funding situation [Does your contract duration affect your work negatively?]
# Contract and funding situation [Do you think there are sufficient funding options to apply to available? ]
# Contract and funding situation [Have you applied for funding yourself? ]
# Contract and funding situation [Have you had a position funded by yourself?]
# How long do you estimate you work on average per week (on a full-time position)?
# Do you think you overwork?
# Why do you overwork? [Self pressure]
# Why do you overwork? [Pressure from my supervisor]
# Why do you overwork? [Pressure from my collaboration]
# Why do you overwork? [Need to compete for the next position]
# Why do you overwork? [Other]
# Do you have the impression that you have or are developing physical symptoms or an impact on your health from overwork?
# We are interested to learn more about your work conditions [Do you often work outside standard working hours? ]
# We are interested to learn more about your work conditions [Is it easy for you to switch off from work?]
# We are interested to learn more about your work conditions [Are you happy with your current work-life balance?]
# How did the pandemic change your attitude on the following items: [Work-life balance]
# How did the pandemic change your attitude on the following items: [Recognition of work]
# How did the pandemic change your attitude on the following items: [Relation with colleagues]
# How did the pandemic change your attitude on the following items: [Motivation for research]
# How did the pandemic change your attitude on the following items: [Motivation for teaching]
# How did the pandemic change your attitude on the following items: [Participation in workshops/conferences]
# How did the pandemic change your attitude on the following items: [Happiness with work]
# How did the pandemic change your attitude on the following items: [Ability to solve conflicts]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Financial][Scale 1]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Financial][Scale 2]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Prolongation of deadlines][Scale 1]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Prolongation of deadlines][Scale 2]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Social support and advice][Scale 1]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Social support and advice][Scale 2]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Contract extension][Scale 1]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Contract extension][Scale 2]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Reduction of teaching duties][Scale 1]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Reduction of teaching duties][Scale 2]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Reduction of workload][Scale 1]
# Did you receive or need one of the following work related supports during the pandemic to mitigate effects:  [Reduction of workload][Scale 2]
# Any other work related support that you received or would have needed to get better through the pandemic?
# How would you rate [The influence of having children on the advancement of a career/studies in science?]
# How would you rate [Your working environment in terms of family friendliness?]
# What would be needed to improve family friendliness?
# Do you want to answer some extra questions on the following topics (only if they apply to you)? [I have a child/children and want to answer some extra questions on compatibility of work and family (2 minutes)]
# Do you want to answer some extra questions on the following topics (only if they apply to you)? [I have elderly or disabled person(s) to take care of and would like to answer some related questions (1 minute)]
# Do you want to answer some extra questions on the following topics (only if they apply to you)? [No, thanks]
# Which of the following holds for you:  [I am working full time]
# Which of the following holds for you:  [My children live with me]
# Which of the following holds for you:  [My partner lives with me]
# Which of the following holds for you:  [My partner works full time]
# Which of the following holds for you:  [My children go to a Kita/Kindergarten/Daycare/School]
# Which of the following holds for you:  [I have additional support in child care by my partner]
# Which of the following holds for you:  [I have additional support in child care by parents]
# Which of the following holds for you:  [I have additional support in child care by babysitter]
# Which of the following holds for you:  [I have additional support in child care by neighbours]
# Which of the following holds for you:  [I have additional support in child care by neighbours others]
# Which of the following holds for you:  [I need additional support in child care]
# Why do you need addtional care?
# Which existing measures to improve family friendliness do you like?
# How would you rate your family-work balance?
# What is the influence of having to take care of elderly people on the advancement of your career/studies?
# Are you supported enough in taking care of elderly people?
# What would be needed?
# What is your long term career wish?
# What is your long term career wish? [Other]
# A few general questions to rate [How good do you see your chances for a permanent job in academia?]
# A few general questions to rate [How good do you see your chances for a permanent job outside academia?]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Publications][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Publications][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Own research profile][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Own research profile][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Going to conferences][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Going to conferences][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Convenerships][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Convenerships][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Networking][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Networking][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Quality of your own research][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Quality of your own research][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Knowing/being known by key people][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Knowing/being known by key people][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Mobility/going abroad][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Mobility/going abroad][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Mentoring ][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Mentoring ][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Third-party funding][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Third-party funding][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Grades during studies / on the PhD][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Grades during studies / on the PhD][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Leadership / management experience][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Leadership / management experience][Scale 2]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Teaching experience][Scale 1]
# We are interested how you would rate the following factors regarding their impact to advance a carreer in science: [Teaching experience][Scale 2]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I am not interested in advancing my career in science]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I proactively work on advancing my career outside science]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I think there is no proactive work required to advance my career in science]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I think that proactive work does not help/change the advancement of a career in science]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I have no additional time due my core duties]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I have no additional time due to private reasons]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I have no additional time due to other reasons]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [I do not want to answer]
# What hinders you from putting more effort into advancing your career in science? Select the most relevant items [Other]
# If you leave academia, what would be your main reasons? [I consider academia as education for a job outside academia]
# If you leave academia, what would be your main reasons? [Curiosity about jobs outside academia]
# If you leave academia, what would be your main reasons? [Bad working conditions in academia]
# If you leave academia, what would be your main reasons? [Unfriendly working environment for a family]
# If you leave academia, what would be your main reasons? [Low pay]
# If you leave academia, what would be your main reasons? [Low chance for a permanent position]
# If you leave academia, what would be your main reasons? [Pressure from family, friends, etc.]
# If you leave academia, what would be your main reasons? [Unsatisfying work (research, teaching, etc.)]
# If you leave academia, what would be your main reasons? [Requirement to move for a next position]
# If you leave academia, what would be your main reasons? [Private reasons]
# If you leave academia, what would be your main reasons? [Other]
# Would you choose HEP again?
# Have you had the impression that you are at a career-related disadvantage due to gender, sexual orientation, ethnicity, disability, etc.?
# Have you had the impression that you are at a career-related disadvantage due to gender, sexual orientation, ethnicity, disability, etc.? [Other]
# Which of the following was a contributing factor to the career-related disadvantage? [Lack of awareness about the disadvantage from people around you]
# Which of the following was a contributing factor to the career-related disadvantage? [Lack of resources to compensate for the disadvantage]
# Which of the following was a contributing factor to the career-related disadvantage? [Cultural barriers to address the disadvantage sufficiently ]
# Which of the following was a contributing factor to the career-related disadvantage? [Other]
# What would help or would have helped you to alleviate the disadvantage?
# We are interested to hear your take on the topic of diversity and inclusion [Do you consider diversity and inclusion an important topic in the work environment of academia?]
# We are interested to hear your take on the topic of diversity and inclusion [How well are measures for diversity and inclusion implemented at your institute?]
# What diversity and inclusion initiative would you like to see implemented in your work environment?
# Do you have the impression that you sometimes suffer from impostor syndrome?
# Do you have the impression that you sometimes suffer from impostor syndrome? [Other]
# Has the feeling of imposter syndrome impacted your work, like hesitancy not to present your research, insecurity in leading a team or project, etc.?
# What has helped you or would have helped you to handle feelings of imposter syndrome better?
# Anything else that you would like to communicate to us?
# Total time
# Group time: General
# Group time: Work situation
# Group time: Financial/contract situation
# Group time: Work-life balance
# Group time: Career paths
# Group time: Diversity and Inclusion
# Group time: Feedback

# %% [markdown]
# # Reproducing the plots in the presentation
#
# The scripts below reproduce the figures in the RECFA visit [slides](https://docs.google.com/presentation/d/1DnN_1kzu5QPZZQkMM-CPSQU3EJpafiP17_E7hzEcy6c/edit#slide=id.g11a4a1ead1d_0_17)

# %% [markdown]
# ## Distribution by Section

# %%
polled_by_section = table['Which yHEP section do you see yourself in?']

labels = polled_by_section.unique()
values = []

for val in labels:
    values.append(sum(polled_by_section == val))

values, labels = np.array(values), np.array(labels)
sorting_sequence = np.argsort(values)[::-1]

values = values[sorting_sequence]
labels = labels[sorting_sequence]

def my_autopct(pct):
    return f'{pct:.0f}%' if pct > 5 else ''

plt.pie(values, labels=labels, counterclock=False, autopct=my_autopct,
        startangle=90, textprops={'fontsize':15, 'wrap':True},
        colors=colorset);

# %% [markdown]
# ## Duration of doctoral studies

# %%
PhDduration1 = table['How long are your doctoral / PhD studies planned to last?']
PhDduration2 = table['How long did it take you to complete your doctorate / PhD?']


labels = ['< 3 years', '3 years', '4 years', '5 years', '> 5 years', 'Other', "I don't know               ", ]
values = []

for duration in labels:
#     values.append(sum(PhDduration1 == duration) + sum(PhDduration2 == duration))
    values.append(sum(PhDduration2 == duration))

plt.pie(values, labels=labels, counterclock=False, startangle=90, textprops={'fontsize':15, 'wrap':True},
        colors=colorset);

plt.gca().set_title('Duration of doctoral/PhD studies', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Duration of doctoral/PhD studies')

# %% [markdown]
# ## General happiness in different categories

# %%
work_situation = table['We are interested to hear about your work situation [Are you happy with your work situation?]']
worklife_balance = table['We are interested to learn more about your work conditions [Are you happy with your current work-life balance?]']
familywork_balance = table['How would you rate your family-work balance?']

figure_labels = ['Work situation', 'Work-life balance', 'Family-Work balance']

f, axes = plt.subplots(1, 3, figsize=(14, 4))

for ax, series, fl in zip(axes, [work_situation, worklife_balance, familywork_balance], figure_labels):

    subser = series.value_counts()
    subser.sort_index(inplace=True)
    if fl != 'Work situation':virtual machine
        
        subser = subser.append(pd.Series({'nan' : 1}))

    ax.set_title(fl, fontsize=20, fontweight='bold')
    ax.pie(subser, labels=subser.keys(), counterclock=False, startangle=90, textprops={'fontsize':15, 'wrap':True},
        colors=colorset);
    
cbax = plt.legend(loc=(1.08, 0.24), fontsize=16)
plt.annotate(xy=(0.8, -1.25), text='*Leftmost pie wrongly counts \nnan values as one, yielding 22 \nanswers instead of 21.', fontsize=16)
# Out:
# Text(0.8, -1.25, '*Leftmost pie wrongly counts \nnan values as one, yielding 22 \nanswers instead of 21.')

# %% [markdown]
# ## What is appreciated and what not

# %%
ScientificFreedom = table['We are interested to hear about your work situation [Do you have sufficient scientific freedom?]']

values = ScientificFreedom.value_counts().sort_index()

def my_autopct(pct):
    return f'{pct:.0f}%' if pct > 5 else ''

plt.pie(values, labels=values.keys(), counterclock=False, autopct=my_autopct,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset);

plt.gca().set_title('Amount of scientific freedom', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Amount of scientific freedom')

# %% [markdown]
# ## Contract situation

# %%
f, axes = plt.subplots(1, 2, figsize=(18, 4))

plt.sca(axes[0])

funding_source = table['How is your current position funded?']

values = funding_source.value_counts()
values = values.append(pd.Series({'No answer' : 1, #sum(funding_source.isna()), # wrongly assuming a smaller number of no answer
                                  'Max Planck institute' : 0}))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [0, 2, 1, 7, 4, 10, 8, 3, 6, 5, 9]]

values = values.reindex(reordered_keys)

def my_autopct(pct):
    return f'{pct:.0f}%' if pct > 5 else ''

plt.pie(values, labels=values.keys(), counterclock=False, autopct=my_autopct,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, labeldistance=None);

plt.gca().set_title('Source of funding', fontsize=20, fontweight='bold')
plt.legend(loc=(1., 0.), fontsize=12)


plt.sca(axes[1])

unemployment_periods = table['A few questions on your contract situation: [Have you ever encountered short periods of unemployment because of non-matching contracts?]']

values = unemployment_periods.value_counts()
values = values.append(pd.Series({'No answer' : 1 #sum(unemployment_periods.isna())
                                 }))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [1, 2, 0, 3]]

values = values.reindex(reordered_keys)

def my_autopct(pct):
    return f'{pct:.0f}%' if pct > 5 else ''

plt.pie(values, labels=values.keys(), counterclock=False, autopct=my_autopct,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, labeldistance=None);

plt.gca().set_title('Encountered periods \nof unemployment', fontsize=20, fontweight='bold')
plt.legend(loc=(1., 0.5), fontsize=12)

# %% [markdown]
# ## Mental Health

# %%
f = plt.figure(figsize=(20, 4), dpi=120)

ax1 = plt.subplot2grid((1,8), (0,0), colspan=5)
ax2 = plt.subplot2grid((1,8), (0,5), colspan=2)
axes = [ax1, ax2]

plt.sca(axes[0])

overwork = table['Do you think you overwork?']

values = overwork.value_counts()
values = values.append(pd.Series({'No answer' : sum(overwork.isna()), #sum(overwork.isna()), # wrongly assuming a smaller number of no answer
                                  'I do not want to answer' : 0}))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [1, 0, 2, 3, 5, 4]]

values = values.reindex(reordered_keys)

def my_autopct(pct):
    return f'{pct:.0f}%' if pct > 5 else ''

plt.pie(values, labels=values.keys(), counterclock=False, autopct=my_autopct,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, labeldistance=None);

plt.gca().set_title('Impression to overwork', fontsize=20, fontweight='bold')
plt.legend(loc=(1., 0.4), fontsize=12)


plt.sca(axes[1])

symptoms = table['Do you have the impression that you have or are developing physical symptoms or an impact on your health from overwork? ']

values = symptoms.value_counts()
values = values.append(pd.Series({'No answer' : 1 #sum(unemployment_periods.isna())
                                 }))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [1, 0, 3, 2, 4, 5]]

values = values.reindex(reordered_keys)


plt.bar(range(len(values)), values, color=colorset);
plt.xticks(range(6), ['1', '2', '3', '4', '5', 'No answer'])
plt.ylabel('Number of replies')

plt.gca().set_title('Impression of an impact on health (incl.\nphysical symptoms) from overwork', fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Impression of an impact on health (incl.\nphysical symptoms) from overwork')

# %% [markdown]
# ## Job opportunities in the field

# %%
f = plt.figure(figsize=(20, 4), dpi=120)

ax1 = plt.subplot2grid((1,8), (0,0), colspan=5)
ax2 = plt.subplot2grid((1,8), (0,5), colspan=2)
axes = [ax1, ax2]

plt.sca(axes[0])

jobs_academia = table['A few general questions to rate [How good do you see your chances for a permanent job in academia?]']

values = jobs_academia.value_counts()
values = values.append(pd.Series({'No answer' : sum(overwork.isna()), #sum(overwork.isna()), # wrongly assuming a smaller number of no answer
                                  }))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [4, 3, 2, 1, 0, 5]]

values = values.reindex(reordered_keys)


plt.pie(values, labels=values.keys(), counterclock=False,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, labeldistance=None);

plt.gca().set_title('Percieved opportunities\nfor a permanent job', fontsize=20, fontweight='bold')
plt.legend(loc=(1., 0.4), fontsize=12)

plt.gca().text(-.01, -.9, 'In academia', rotation=35, fontsize=15)

# ---- Inset plot
ax3 = f.add_axes([.164, .3, .4, .4])
plt.sca(ax3)

jobs_outside_academia = table['A few general questions to rate [How good do you see your chances for a permanent job outside academia?]']
values = jobs_outside_academia.value_counts()

plt.pie(values, labels=values.keys(), counterclock=False,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, labeldistance=None);

plt.gca().text(-.8, -.6, 'Outside\nacademia', rotation=35, fontsize=15)

plt.sca(axes[1])

vals_dict = {}

for kt in table.keys():
    if kt.startswith('If you leave'):
        vals_dict[kt[kt.index('[')+1:kt.index(']')]] = sum(table[kt] == 'Yes')
vals_dict['Other'] = 4 # differs from slides, don't know why


from textwrap import wrap
for kt, c in zip(vals_dict.keys(), colorset):
    lab = '\n'.join(wrap(kt, 20))
    plt.plot([], [], ls='', marker='s', ms=11, color=c, label=lab)


plt.bar(range(len(vals_dict.keys())), vals_dict.values(), color=colorset);
plt.xticks(range(11), ('',)*11)
plt.ylabel('Number of replies')

plt.gca().set_title('Main reasons to leave', fontsize=20, fontweight='bold')
plt.legend(loc=(1.01, -.05))

# %% [markdown]
# ## Gender balance

# %%
disadvantage = table['Have you had the impression that you are at a career-related disadvantage due to gender, sexual orientation, ethnicity, disability, etc.?']
gender = table['What is your gender?']

values = disadvantage[gender == 'Female'].value_counts()
values = values.append(pd.Series({'No answer' : 1}))


original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [1, 0, 2, 3, 4]]
values = values.reindex(reordered_keys)


f, ax = plt.subplots(dpi=120)

plt.pie(values, labels=values.keys(), counterclock=False, labeldistance=None, 
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset);

plt.gca().set_title('Impression of a career-related disadvantage due to\ngender, sexual orientation, ethnicity, disability, etc.', fontsize=12, fontweight='bold')
plt.legend(loc=(1., 0.4), fontsize=12)

plt.gca().text(.1, -.85, 'Women', rotation=35, fontsize=15)


f.add_axes([.313, .3, .4, .4])

values = disadvantage[gender == 'Male'].value_counts()
values = values.append(pd.Series({'No answer' : 1}))


original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [1, 0, 2, 3, 4]]
values = values.reindex(reordered_keys)


plt.pie(values, labels=values.keys(), counterclock=False, labeldistance=None, shadow=True,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, wedgeprops={'linewidth':5});

plt.gca().text(-.3, -.5, 'Men', rotation=35, fontsize=15)
# Out:
# Text(-0.3, -0.5, 'Men')

# %% [markdown]
# ## Sustainability and diversity

# %%
importance = table['We are interested to hear your opinion on environmental sustainability in science [How important is environmental sustainability in science to you?]']
implement = table['We are interested to hear your opinion on environmental sustainability in science [How well do you think sustainability in science is approached in your project / institute?]']

values = importance.value_counts()
values = values.append(pd.Series({'No answer' : sum(importance.isna())}))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [0, 1, 2, 4, 3, 5]]
values = values.reindex(reordered_keys)

f, axes = plt.subplots(1, 2, dpi=120, figsize=(10, 4))
plt.sca(axes[0])
plt.pie(values, labels=values.keys(), counterclock=False, labeldistance=None, 
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset);

plt.gca().set_title('Environmental sustainability', fontsize=12, fontweight='bold')
plt.gca().text(-.02, -.85, 'Importance', rotation=35, fontsize=15)



values = implement.value_counts()
values = values.append(pd.Series({'No answer' : sum(implement.isna())}))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [4, 2, 0, 1, 3, 5]]
values = values.reindex(reordered_keys)


f.add_axes([.101, .3, .4, .4])

plt.pie(values, labels=values.keys(), counterclock=False, labeldistance=None, shadow=True,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, wedgeprops={'linewidth':5});

plt.gca().text(-.5, -.9, 'Implemen-\ntation', rotation=35, fontsize=14)





# ------------------------------------------------
plt.sca(axes[1])

importance = table['We are interested to hear your take on the topic of diversity and inclusion [Do you consider diversity and inclusion an important topic in the work environment of academia?]']
implement = table['We are interested to hear your take on the topic of diversity and inclusion [How well are measures for diversity and inclusion implemented at your institute?]']

values = importance.value_counts()
values = values.append(pd.Series({'No answer' : sum(importance.isna())}))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [0, 1, 2, 4, 3, 5]]
values = values.reindex(reordered_keys)

plt.pie(values, labels=values.keys(), counterclock=False, labeldistance=None, 
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset);

plt.gca().set_title('Diversity and inclusion', fontsize=12, fontweight='bold')
plt.legend(loc=(1., 0.4), fontsize=12)

plt.gca().text(-.02, -.85, 'Importance', rotation=35, fontsize=15)




values = implement.value_counts()
values = values.append(pd.Series({'No answer' : sum(implement.isna())}))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [2, 0, 1, 3, 4, 5]]
values = values.reindex(reordered_keys)


f.add_axes([.525, .3, .4, .4])

plt.pie(values, labels=values.keys(), counterclock=False, labeldistance=None, shadow=True,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, wedgeprops={'linewidth':5});
plt.gca().text(-.5, -.9, 'Implemen-\ntation', rotation=35, fontsize=14)
# Out:
# Text(-0.5, -0.9, 'Implemen-\ntation')

# %% [markdown]
# ## Job opportunities in the field

# %%
f = plt.figure(figsize=(20, 4), dpi=120)

ax1 = plt.subplot2grid((1,8), (0,0), colspan=4)
ax2 = plt.subplot2grid((1,8), (0,4), colspan=2)
axes = [ax1, ax2]

plt.sca(axes[0])

overwork = table['Would you choose HEP again?']

values = overwork.value_counts()
values = values.append(pd.Series({'No answer' : sum(overwork.isna()), #sum(overwork.isna()), # wrongly assuming a smaller number of no answer
                                  'I do not want to answer' : 0}))

original_keys = values.keys()
reordered_keys = [original_keys[l] for l in [0, 3, 1, 2, 4, 5]]

values = values.reindex(reordered_keys)

def my_autopct(pct):
    return f'{pct:.0f}%' if pct > 5 else ''

plt.pie(values, labels=values.keys(), counterclock=False, autopct=my_autopct,
        startangle=90, textprops={'fontsize':15, 'wrap':True}, colors=colorset, labeldistance=None);

plt.gca().set_title('Willingness to choose HEP again', fontsize=18, fontweight='bold')
plt.legend(loc=(1., 0.4), fontsize=12)


plt.sca(axes[1])

vals_dict = {}

for kt in table.keys():
    if kt.startswith('Why are you working/studying in HEP?'):
        vals_dict[kt[kt.index('[')+1:kt.index(']')]] = sum(table[kt] == 'Yes')
vals_dict['Other'] = 4 # differs from slides, don't know why


from textwrap import wrap
for kt, c in zip(vals_dict.keys(), colorset):
    lab = '\n'.join(wrap(kt, 20))
    plt.plot([], [], ls='', marker='s', ms=11, color=c, label=lab)


plt.bar(range(len(vals_dict.keys())), vals_dict.values(), color=colorset);
plt.xticks(range(6), ('',)*6)
plt.ylabel('Number of replies')

plt.gca().set_title('Reason for choosing HEP', fontsize=20, fontweight='bold')
plt.legend(loc=(.71, .3))
